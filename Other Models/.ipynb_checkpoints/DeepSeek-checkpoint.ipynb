# %%
import os, json, pathlib, re, ast
from openai import OpenAI 
import openai
from tqdm import tqdm
import pandas as pd
from dotenv import find_dotenv, load_dotenv
from typing import List, Dict, Optional
from langchain.vectorstores import FAISS
from langchain.docstore.document import Document
from langchain_openai import OpenAIEmbeddings

# %%
# Load API
load_dotenv()
OPENAI_KEY = os.getenv("OPENAI_API_KEY")
OLLAMA_BASE = "http://localhost:11434/v1" 
MODEL_NAME = "llama3:8b-instruct-q4_K_M" 
TEMPERATURE = 1.0

ollama_client = OpenAI(base_url=OLLAMA_BASE, api_key="ollama")
print("Ollama client ready →", OLLAMA_BASE, "model:", MODEL_NAME)


# Index file
INDEX_DIR = pathlib.Path("faiss_disaster_information_index")

# Load files
src_file  = "../data/disaster_description.csv"
out_file  = "extracted_llama.csv"
df = pd.read_csv(src_file)
# df = df.head(200)
# Out:
# Ollama client ready → http://localhost:11434/v1 model: llama3:8b-instruct-q4_K_M

# %% [markdown]
# # FAISS Vectorstore

# %%
DISASTER_CLASSIFICATION = json.load(open("../data/classification_document.json"))

# %%
MAGNITUDE_INFORMATION = json.load(open("../data/magnitude_document.json"))

# %%
FIELD_SCHEMA = json.load(open("../data/schema_document.json"))

# %%
EXAMPLES = pathlib.Path("../data/Examples.txt").read_text(encoding="utf-8")

# %%
disaster_docs = []
groups = DISASTER_CLASSIFICATION["Disaster Group"]
for group_name, meta in groups.items():
        desc  = meta.get("Description", "")
        types = meta.get("Disaster Types", {})

        block = f"### Disaster Group: {group_name}\n{desc}\n\nDisaster Types:\n"
        for t_name, t_desc in types.items():
            block += f"- {t_name}: {t_desc}\n"

        doc = Document(
            page_content = block.strip(),
            metadata     = {"group": group_name, "level": "G1"}
        )
        disaster_docs.append(doc)

# %%
magnitude_docs = []
for dtype, info in MAGNITUDE_INFORMATION.items():
    block = (
        f"### Magnitude Guidance\n"
        f"Disaster Type: {dtype}\n"
        f"Property      : {info['property']}\n"
        f"Unit          : {info['unit']}"
    )

    doc = Document(
        page_content = block,
        metadata     = {"type" : dtype, "level": "M1" }
    )
    magnitude_docs.append(doc)

# %%
fields_docs = []
for section_name, fields in FIELD_SCHEMA.items():
    for fname, meta in fields.items():
        block = (
            f"### Field: {fname}\n"
            f"Section      : {section_name}\n"
            f"Type         : {meta['Type']}\n"
            f"Description  : {meta.get('Description', meta.get('Rescription',''))}"
        )

        doc = Document(
            page_content = block,
            metadata = {"section": section_name, "field"  : fname, "level"  : "F0"
                }
        )
        fields_docs.append(doc)

# %%
examples_docs = []
block = re.split(r"Example\s+\d+:\s*", EXAMPLES)[1:]

for idx, chunk in enumerate(block, start=1):
    doc = Document(
        page_content = chunk.strip(),
        metadata     = {"example_id": idx, "level": "E1"}
    )
    examples_docs.append(doc)

# %%
for k in ("OPENAI_BASE_URL", "OPENAI_API_BASE"):
    os.environ.pop(k, None)

EMB_MODEL = "text-embedding-3-small"
emb = OpenAIEmbeddings(model=EMB_MODEL, api_key=OPENAI_KEY)

if INDEX_DIR.exists():
    vectorstore = FAISS.load_local(
        str(INDEX_DIR),
        embeddings=emb,  
        allow_dangerous_deserialization=True
    )
else:
    print("Building FAISS index from scratch … ")

    vectorstore = FAISS.from_documents(disaster_docs, emb) 
    vectorstore.add_documents(magnitude_docs)
    vectorstore.add_documents(fields_docs)
    vectorstore.add_documents(examples_docs)
    vectorstore.save_local(str(INDEX_DIR))

print(f"✅  Vectorstore ready, ntotal = {vectorstore.index.ntotal}")
# Out:
# ✅  Vectorstore ready, ntotal = 41

# %% [markdown]
# # Prompt

# %%
OUTPUT_FIELDS = {
  "Event": "fields name",
  "Geographical Information": "fields name",
  "Effect": "fields name"
}

# %%
OUTPUT_VALUES = {
  "Event": {"fields": "values"},
  "Geographical Information": {"fields": "values"},
  "Effect": {"fields": "values"}
}

# %%
def restructure_example(doc: Document):
    
    txt = doc.page_content

    # description
    e_desc = re.search(r"Description:\s*(.*?)\s*Fields output:", txt, re.S)
    if not e_desc:
        raise ValueError(f"Did not find description, example_id={doc.metadata.get('example_id')}")
    description = e_desc.group(1).strip()

    # fields / values
    e_fields = re.search(r"Fields output:\s*(\{.*?\})\s*Values output:", txt, re.S)
    e_values = re.search(r"Values output:\s*(\{.*\})\s*$", txt, re.S)
    
    if not (e_fields and e_values):
        raise ValueError(f"Did not find description fields/values, example_id={doc.metadata.get('example_id')}")

    example_fields  = ast.literal_eval(e_fields.group(1).strip())
    example_values  = ast.literal_eval(e_values.group(1).strip())

    # restructure
    stage1 = {
        "description":    description,
        "output_fields":  example_fields,
    }
    stage2 = {
        "description":    description,
        "output_values":  example_values,
    }
    return stage1, stage2

# %%
def fields_extraction_prompt (example1: Document, example2: Document) -> str:
    
    stage1_dict1, _ = restructure_example(example1)
    stage1_dict2, _ = restructure_example(example2)
    
    prompt = f"""
        Please refer FIELD_SCHEMA first, then list every field that is
        mentioned (even once) or is marked as 'Required' in DISASTER_DESCRIPTION. 
        Output must contain field names only.
        Finally return a single JSON object that conforms precisely to OUTPUT_FIELDS.
        Below there are two reference EXAMPLE1_STAGE1 and EXAMPLE2_STAGE1 
        for one disaster's description and its output fields.
        Return ONLY one valid minified JSON object.
        
        FIELD_SCHEMA:
        {json.dumps(FIELD_SCHEMA, ensure_ascii=False)}

        OUTPUT_FIELDS:
        {json.dumps(OUTPUT_FIELDS, ensure_ascii=False)}

        EXAMPLE_STAGE1:
        {json.dumps(stage1_dict1, ensure_ascii=False, indent=4)}

        EXAMPLE2_STAGE1:
        {json.dumps(stage1_dict2, ensure_ascii=False, indent=4)}

    """
    return prompt

# %%
def values_extraction_prompt(
    fields_docs: List[Document], 
    example: Document,
    categorical_values: Optional[Document]
) -> str:
    
    PROMPT = """
    Please extract all information regarding only the fields in EXTRACTED_FIELDS 
    from text DISASTER_DESCRIPTION (refering the information in FIELD_SCHEMA and using only 
    the categorical options in CATEGORICAL_VALUES). 
    Finally return a single JSON object that conforms precisely to OUTPUT_VALUES.
    Below there is a reference EXAMPLE_STAGE2 for one disaster's description and its output values.
    Return ONLY one valid minified JSON object.
"""

    parts = ["FIELD_SCHEMA:"]
    parts += [d.page_content for d in fields_docs]

    parts += ["CATEGORICAL_VALUES:"]
    parts += [d.page_content for d in categorical_values] 

    parts += [
        "OUTPUT_VALUES:",
        json.dumps(OUTPUT_VALUES, ensure_ascii=False)
    ]

    _, stage2_dict= restructure_example(example)
    parts += ["EXAMPLE_STAGE2:",
              json.dumps(stage2_dict, ensure_ascii=False, indent=4)]
    
    return PROMPT + "\n\n" + "\n\n".join(parts)

# %% [markdown]
# # Implement

# %%
def _brace_scan(s: str):
    if not s:
        return None
    stack, start = [], None
    for i, ch in enumerate(s):
        if ch in "{[":
            if not stack:
                start = i
            stack.append(ch)
        elif ch in "}]":
            if not stack:
                continue
            left = stack.pop()
            if (left == "{" and ch == "}") or (left == "[" and ch == "]"):
                if not stack and start is not None:
                    candidate = s[start:i+1]
                    try:
                        return json.loads(candidate)
                    except Exception:
                        pass
    return None

# %%
def extract_json_from_text(text: str):
    if not text:
        return None
    text = text.strip()

    # 1) JSON Format
    if text and text[0] in "[{":
        try:
            return json.loads(text)
        except Exception:
            pass

    # 2) ```json ... ```
    m = re.search(r"```(?:json|JSON)?\s*([\s\S]*?)\s*```", text)
    if m:
        candidate = m.group(1).strip()
        try:
            return json.loads(candidate)
        except Exception:
            parsed = _brace_scan(candidate)
            if parsed is not None:
                return parsed

    # 3) Find the first {} or []
    parsed = _brace_scan(text)
    if parsed is not None:
        return parsed

    return None

# %%
"""
def call_llm(prompt_text: str, description_text: str, extracted_fields_text = None) -> dict:
    
    if extracted_fields_text is None:
        user_content = description_text or ""
    else:
        user_content = json.dumps({
            "DISASTER_DESCRIPTION": description_text,
            "EXTRACTED_FIELDS": extracted_fields_text
        }, ensure_ascii=False)
        
    def _ask(sys_prompt: str, user_msg: str):
        return ollama_client.chat.completions.create(
            model=MODEL_NAME,
            messages=[
                {"role": "system", "content": sys_prompt},
                {"role": "user",   "content": user_msg}
            ],
            temperature=1.0,
            extra_body={
                "format": "json",
                "options": {"num_ctx": 8192, "num_predict": 768}
            }
        )

    last_text = None

    # 1) 第一次：按业务 prompt 直接生成
    try:
        resp = _ask(prompt_text, user_content)
        text = (resp.choices[0].message.content or "").strip()
        last_text = text

        # 先直 parse，再用你的提取器兜底
        if text.startswith("{") or text.startswith("["):
            try:
                return json.loads(text)
            except Exception:
                pass
        parsed = extract_json_from_text(text)
        if parsed is not None:
            return parsed
    except Exception as e:
        print("[DeepSeek] generation error:", e)

    # 2) 解析失败 → 进入“修复器”重试若干次（不重做抽取，只把 last_text 修成 JSON）
    for attempt in range(1, 3):
        try:
            fix_sys = (
                "You are a JSON fixer. Convert the following content into ONE valid minified JSON "
                "object that matches the expected schema hinted by the content. "
                "Do not add explanations or code fences. Output ONLY the JSON."
            )
            resp2 = _ask(fix_sys, last_text)
            text2 = (resp2.choices[0].message.content or "").strip()

            if text2.startswith("{") or text2.startswith("["):
                try:
                    return json.loads(text2)
                except Exception:
                    pass

            parsed2 = extract_json_from_text(text2)
            if parsed2 is not None:
                return parsed2

            # 失败就把这次的输出作为下次修复的输入
            last_text = text2
            print(f"[WARN] JSON fix attempt {attempt} failed. Head:", repr(text2[:160]))

        except Exception as e:
            print(f"[DeepSeek] fix error on attempt {attempt}:", e)

    # 全部失败
    print("[WARN] Still not valid JSON after retries. Head:", repr((last_text or "")[:160]))
    return None  # 若想保留原文用于排查，可改成：return {"raw": last_text}
"""
# Out:
# '\ndef call_llm(prompt_text: str, description_text: str, extracted_fields_text = None) -> dict:\n    \n    if extracted_fields_text is None:\n        user_content = description_text or ""\n    else:\n        user_content = json.dumps({\n            "DISASTER_DESCRIPTION": description_text,\n            "EXTRACTED_FIELDS": extracted_fields_text\n        }, ensure_ascii=False)\n        \n    def _ask(sys_prompt: str, user_msg: str):\n        return ollama_client.chat.completions.create(\n            model=MODEL_NAME,\n            messages=[\n                {"role": "system", "content": sys_prompt},\n                {"role": "user",   "content": user_msg}\n            ],\n            temperature=1.0,\n            extra_body={\n                "format": "json",\n                "options": {"num_ctx": 8192, "num_predict": 768}\n            }\n        )\n\n    last_text = None\n\n    # 1) 第一次：按业务 prompt 直接生成\n    try:\n        resp = _ask(prompt_text, user_content)\n        text = (resp.choices[0].message.content or "").strip()\n        last_text = text\n\n        # 先直 parse，再用你的提取器兜底\n        if text.startswith("{") or text.startswith("["):\n            try:\n                return json.loads(text)\n            except Exception:\n                pass\n        parsed = extract_json_from_text(text)\n        if parsed is not None:\n            return parsed\n    except Exception as e:\n        print("[DeepSeek] generation error:", e)\n\n    # 2) 解析失败 → 进入“修复器”重试若干次（不重做抽取，只把 last_text 修成 JSON）\n    for attempt in range(1, 3):\n        try:\n            fix_sys = (\n                "You are a JSON fixer. Convert the following content into ONE valid minified JSON "\n                "object that matches the expected schema hinted by the content. "\n                "Do not add explanations or code fences. Output ONLY the JSON."\n            )\n            resp2 = _ask(fix_sys, last_text)\n            text2 = (resp2.choices[0].message.content or "").strip()\n\n            if text2.startswith("{") or text2.startswith("["):\n                try:\n                    return json.loads(text2)\n                except Exception:\n                    pass\n\n            parsed2 = extract_json_from_text(text2)\n            if parsed2 is not None:\n                return parsed2\n\n            # 失败就把这次的输出作为下次修复的输入\n            last_text = text2\n            print(f"[WARN] JSON fix attempt {attempt} failed. Head:", repr(text2[:160]))\n\n        except Exception as e:\n            print(f"[DeepSeek] fix error on attempt {attempt}:", e)\n\n    # 全部失败\n    print("[WARN] Still not valid JSON after retries. Head:", repr((last_text or "")[:160]))\n    return None  # 若想保留原文用于排查，可改成：return {"raw": last_text}\n'

# %%
def call_llm(prompt_text: str, description_text: str, extracted_fields_text=None) -> dict:
    if extracted_fields_text is None:
        user_content = description_text or ""
    else:
        user_content = json.dumps({
            "DISASTER_DESCRIPTION": description_text,
            "EXTRACTED_FIELDS": extracted_fields_text
        }, ensure_ascii=False)

    def _ask(sys_prompt: str, user_msg: str):
        return ollama_client.chat.completions.create(
            model=MODEL_NAME,
            messages=[
                {"role": "system", "content": sys_prompt},
                {"role": "user",   "content": user_msg}
            ],
            temperature=1.0, 
            extra_body={
                "format": "json",
                "options": {"num_ctx": 16384, "num_predict": 768}
            }
        )

    last_head = ""

    try:
        resp = _ask(prompt_text, user_content)
        text = (resp.choices[0].message.content or "").strip()
        parsed = extract_json_from_text(text)
        if parsed is not None:
            return parsed
        last_head = repr(text[:160])
    except Exception as e:
        print("[GEN] error:", e)

    for i in range(1, 3):
        try:
            resp2 = _ask(prompt_text, user_content)
            text2 = (resp2.choices[0].message.content or "").strip()
            parsed2 = extract_json_from_text(text2)
            if parsed2 is not None:
                return parsed2
            last_head = repr(text2[:160])
            print(f"[WARN] Regen attempt {i} still not JSON. Head: {last_head}")
        except Exception as e:
            print(f"[GEN] error on regen {i}:", e)

    # 3) 全部失败
    print("[WARN] Still not valid JSON after regenerations. Head:", last_head)
    return None  # 也可以改成 return {"raw": text2} 以便排查

# %%
def process_record(description: str) -> dict:
    if not isinstance(description, str):
        return None 

    # examples
    e1_docs = vectorstore.similarity_search(
        description, 
        k=2,
        filter={"level": "E1"}
    )
    if len(e1_docs) < 2:
        used_ids = {d.metadata.get("example_id") for d in e1_docs}
        candidates = [d for d in examples_docs if d.metadata.get("example_id") not in used_ids]
        while len(e1_docs) < 2 and candidates:
            e1_docs.append(candidates.pop())
    
    # Stage1: fields
    p1 = fields_extraction_prompt(e1_docs[0], e1_docs[1])
    r1 = call_llm(p1, description)

    if not isinstance(r1, dict) or r1 is None:
        return None
    
    # Stage2: values
    # 2-1: fields_docs
    if not isinstance(r1, dict):
        return None

    field_list = []
    ok = True
    for v in r1.values():
        if not isinstance(v, list) or not all(isinstance(x, str) for x in v):
            ok = False
            break
        field_list.extend(v)

    if not ok or not field_list:
        return None
   
    
    f0_docs = []
    for fname in field_list:
        doc = vectorstore.similarity_search(
            description,
            k=1,
            filter={"level": "F0", "field": fname}
        )
        if doc:
            f0_docs.append(doc[0])
        else:
            # fallback
            field_doc_map = {d.metadata["field"]: d.page_content for d in fields_docs}
            f0_docs.append(
                Document(
                    page_content=field_doc_map.get(fname, ""),
                    metadata={"level": "F0", "field": fname}
                )
            )
    
    # 2-2: categorical values
    g1_docs = vectorstore.similarity_search(
        description,
        k=2,
        filter={"level": "G1"}
    )
    
    m1_doc = None
    if {"Magnitude", "Magnitude Scale"} & set(field_list):
        hits = vectorstore.similarity_search(
            description,
            k=1,
            filter={"level": "M1"}
        )
        m1_doc = hits[0] if hits else None

    categorical_values = g1_docs + ([m1_doc] if m1_doc else [])


    
    # 2-3: extraction
    p2 = values_extraction_prompt(
        fields_docs      = f0_docs,
        example = e1_docs[0],
        categorical_values = categorical_values
    )
    r2 = call_llm(p2, description, r1)
    
    if r2 is None:
        return None
    
    return {
        "llama_fields": json.dumps(r1, ensure_ascii=False),
        "llama_values": json.dumps(r2, ensure_ascii=False)
    }

# %%
results = []
for desc in tqdm(df["description"], desc="Processing"):
    out = process_record(desc)
    if out is None:
        results.append({"llama_fields": None, "llama_values": None})
    else:
        results.append(out)

df_out = pd.concat(
    [df.reset_index(drop=True), pd.DataFrame(results)],
    axis=1
)

df_out.to_csv(out_file, index=False)
print(f"Output saved to {out_file}")
# Out:
# Processing:   2%|▍                         | 29/1588 [15:47<14:47:23, 34.15s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the list of fields mentioned or required:\n\n- Disaster Group\n- Disaster Type\n- Disaster Date (YMD)\n- Country\n- Location\n- Number of affected'
# Processing:   3%|▊                         | 47/1588 [25:29<16:39:08, 38.90s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the given description, I will extract the required fields and return a valid minified JSON object.\n\nThe required fields are:\n\n* Event: Disaster Group, '
# Processing:   3%|▊                         | 49/1588 [28:00<25:39:43, 60.03s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Based on the provided information, the corresponding fields that are mentioned (even once) or are marked as 'Required' in DISASTER_DESCRIPTION are:\n\n- Event\n- D"
# Processing:   4%|▉                         | 57/1588 [32:03<13:59:18, 32.89s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'The field names mentioned in the disaster description are:\n\n* Disaster Group\n* Disaster Type\n* Disaster Date (YMD)\n* Cause\n* Country\n* Geographical Level 0\n* Lo'
# Processing:   4%|█                         | 64/1588 [36:07<15:59:47, 37.79s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the required fields:\n\n1. Event:\n   - "Disaster Group"\n   - "Disaster Type"\n   - "Disaster Date (YMD)"\n   - "Cause"\n\n2. Geographical Information:\n   - "'
# Processing:   4%|█                         | 65/1588 [36:51<16:43:54, 39.55s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Here are the fields mentioned or marked as 'Required' in DISASTER_DESCRIPTION:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Country"
# Processing:   4%|█                         | 68/1588 [38:57<17:35:56, 41.68s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'The following fields are mentioned in the disaster description:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Cause\n\nThe required geospatial inf'
# Processing:   4%|█▏                        | 69/1588 [39:20<15:12:21, 36.04s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the list of mentioned fields in the provided description:\n\n- Disaster Group\n- Disaster Type\n- Disaster Date (YMD)\n- Cause\nCountry\nGeographical Level 0\nG'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the list of mentioned fields in the provided description:\n\n- Disaster Group\n- Disaster Type\n- Disaster Date (YMD)\n- Cause\nCountry\nGeographical Level 0\nG'
# [WARN] Regen attempt 1 still not JSON. Head: "Based on FIELD_SCHEMA and DISASTER_DESCRIPTION, the fields that are mentioned or marked as 'Required' are:\n\n1. Event: Disaster Group, Disaster Type\n2. Geographi"
# Processing:   4%|█▏                        | 70/1588 [39:35<12:38:41, 29.99s/it]
# [WARN] Regen attempt 2 still not JSON. Head: "From the provided text, we need to list every field mentioned (even once) or marked as 'Required' in DISASTER_DESCRIPTION.\n\nHere are the mentioned fields:\n\n- Di"
# [WARN] Still not valid JSON after regenerations. Head: "From the provided text, we need to list every field mentioned (even once) or marked as 'Required' in DISASTER_DESCRIPTION.\n\nHere are the mentioned fields:\n\n- Di"
# Processing:   5%|█▎                        | 77/1588 [42:27<10:58:17, 26.14s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the mentioned fields:\n\n* Disaster Group\n* Disaster Type\n* Disaster Date (YMD)\n* Country\n* Geographical Level 0\n* Number of Deaths\n* Number of affected'
# Processing:   7%|█▋                       | 108/1588 [58:58<12:48:53, 31.17s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the FIELD_SCHEMA, I can identify the fields mentioned in the given text:\n\n* Disaster Group\n* Disaster Type\n* Cause\n* Country\n* Geographical Level 0\n* G'
# Processing:   7%|█▊                        | 111/1588 [59:42<7:46:58, 18.97s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Event: \n- Disaster Group\n- Disaster Type\n- Disaster Date (YMD)\n- Cause\n- Magnitude\n- Magnitude Scale\n\nGeographical Information: \n- Country\n- Geographical Level '
# Processing:   7%|█▊                        | 112/1588 [59:52<6:43:04, 16.39s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here are the fields mentioned in the disaster description:\n\n1. Event\n2. Geographical Information\n3. Effect'
# [WARN] Still not valid JSON after regenerations. Head: 'Here are the fields mentioned in the disaster description:\n\n1. Event\n2. Geographical Information\n3. Effect'
# Processing:   8%|█▊                     | 122/1588 [1:05:44<12:49:42, 31.50s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "After analyzing the provided text and schema, I extracted the relevant information according to the specified fields in EXTRACTED_FIELDS. Here's the output JSON"
# Processing:   8%|█▊                     | 127/1588 [1:08:54<12:21:32, 30.45s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided text and schema, I extracted the relevant information for each field in EXTRACTED_FIELDS. Here is the resulting JSON object:\n\n```\n{\n    "E'
# Processing:   8%|█▊                     | 128/1588 [1:09:36<13:40:22, 33.71s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the provided text and schema, I will extract the information for the requested fields.\n\n**Event**\n* Disaster Group: Hydrological\n* Disaster Type: Flood'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the provided text and schema, I will extract the information for the requested fields.\n\n**Event**\n* Disaster Group: Hydrological\n* Disaster Type: Flood'
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided text and variables, I will extract the necessary information and return a single JSON object that conforms precisely to OUTPUT_VALUES.\n\nHe'
# Processing:   8%|█▊                     | 129/1588 [1:10:26<15:44:42, 38.85s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the required fields mentioned in the disaster description:\n\nEvent:\n* Disaster Group\n* Disaster Type\n* Disaster Date (YMD)\n* Cause\n\nGeographical Informa'
# Processing:   8%|█▉                     | 130/1588 [1:10:41<12:46:43, 31.55s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here are the required field names:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Country\n5. Geographical Level 0\n7. Number of Deaths\n8. Number o'
# [WARN] Still not valid JSON after regenerations. Head: 'Here are the required field names:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Country\n5. Geographical Level 0\n7. Number of Deaths\n8. Number o'
# Processing:   8%|█▉                     | 131/1588 [1:11:20<13:40:39, 33.79s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'After extracting the relevant information from the DISASTER_DESCRIPTION text using only the categorical options in CATEGORICAL_VALUES, we get:\n\n```\n{\n    "Event'
# Processing:   8%|█▉                     | 132/1588 [1:12:07<15:15:22, 37.72s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the extracted JSON object:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n        "Disaster Date (YMD'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the extracted JSON object:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n        "Disaster Date (YMD'
# Processing:   8%|█▉                     | 133/1588 [1:12:34<13:57:44, 34.55s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'The required fields from this disaster description are:\n\n1. Disaster Group\n2. Disaster Type\n3. Cause'
# Processing:   9%|█▉                     | 135/1588 [1:13:45<14:15:23, 35.32s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the text, the following fields are mentioned or required:\n\n* Event:\n\t+ Disaster Group\n\t+ Disaster Type\n\t+ Disaster Date (YMD)\n\t+ Cause\n\t+ Magnitude\n\t+ '
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Biological",\n        "Disaster Type": "Epidemic",\n        "Disaster Date (YM'
# Processing:   9%|█▉                     | 136/1588 [1:14:41<16:47:42, 41.64s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'From the given text, I will extract only the fields specified in EXTRACTED_FIELDS:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Biological",\n        "Disast'
# [WARN] Still not valid JSON after regenerations. Head: 'From the given text, I will extract only the fields specified in EXTRACTED_FIELDS:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Biological",\n        "Disast'
# Processing:   9%|██                     | 141/1588 [1:17:10<11:14:32, 27.97s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'After extracting the required information, I obtain:\n\n```\nOUTPUT_VALUES:\n{\n    "Event": {\n        "Disaster Group": "Climatological",\n        "Disaster Type": "'
# Processing:   9%|██                     | 142/1588 [1:17:57<13:36:21, 33.87s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the extracted information in JSON format:\n\n{"output_values": {\n    "Event": {\n        "Disaster Group": "Climatological",\n        "Disaster Type": None,'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the extracted information in JSON format:\n\n{"output_values": {\n    "Event": {\n        "Disaster Group": "Climatological",\n        "Disaster Type": None,'
# Processing:  11%|██▍                    | 168/1588 [1:32:05<12:55:29, 32.77s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'The mentioned fields that are mentioned (even once) or marked as \'Required\' in DISASTER_DESCRIPTION are:\n\n1. "Disaster Group"\n2. "Disaster Type"\n3. "Country"\n4.'
# Processing:  11%|██▍                    | 169/1588 [1:32:28<11:48:10, 29.94s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'All the fields mentioned in FIELD_SCHEMA that are required or used at least once in the disaster description are:\n\nEvent:\n- Disaster Group\n- Disaster Type\n- Dis'
# [WARN] Still not valid JSON after regenerations. Head: 'All the fields mentioned in FIELD_SCHEMA that are required or used at least once in the disaster description are:\n\nEvent:\n- Disaster Group\n- Disaster Type\n- Dis'
# Processing:  11%|██▍                    | 172/1588 [1:34:11<12:44:41, 32.40s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the DISASTER_DESCRIPTION and EXRACTED_FIELDS, I extracted the relevant information as follows:\n\n**DISASTER_DESCRIPTION:** \n"On 26 September, the Federa'
# Processing:  11%|██▌                    | 175/1588 [1:35:43<11:14:00, 28.62s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'According to the provided information, we can extract the mentioned fields and create a JSON object that conforms precisely to OUTPUT_FIELDS.\n\nHere are the extr'
# Processing:  11%|██▌                    | 180/1588 [1:37:42<10:21:46, 26.50s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'To solve this problem, we need to identify the required fields mentioned in FIELD_SCHEMA that are not repeated and marked as `Required` in DISASTER_DESCRIPTION.'
# Processing:  12%|██▉                     | 191/1588 [1:43:40<9:48:13, 25.26s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information in a single JSON object:\n\n```\n{\n    "Event": {\n        "fields": {\n            "Disaster Group": "Meteorological",\n           '
# Processing:  12%|██▊                    | 192/1588 [1:44:30<12:37:40, 32.57s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the DISASTER_DESCRIPTION and EXTRACTED_FIELDS provided, here is a JSON object that conforms to OUTPUT_VALUES:\n\n{\n    "Event": {\n        "Disaster Group'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the DISASTER_DESCRIPTION and EXTRACTED_FIELDS provided, here is a JSON object that conforms to OUTPUT_VALUES:\n\n{\n    "Event": {\n        "Disaster Group'
# [WARN] Regen attempt 1 still not JSON. Head: 'The list of fields mentioned in the Disaster Description:\n\n* Disaster Group\n* Disaster Type\n* Date (YMD)\n* Cause\n* Magnitude\n* Country\n* Geographical Level 0\n* '
# Processing:  12%|██▊                    | 193/1588 [1:44:48<10:57:07, 28.26s/it]
# [WARN] Regen attempt 2 still not JSON. Head: "Field names mentioned or marked as 'Required':\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Country\n5. Geographical Level 0 \n6. Number of Deaths"
# [WARN] Still not valid JSON after regenerations. Head: "Field names mentioned or marked as 'Required':\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Country\n5. Geographical Level 0 \n6. Number of Deaths"
# Processing:  12%|██▉                     | 196/1588 [1:46:03<9:36:04, 24.83s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'From the given DESCRIPTION:\n\n1. Fields that are mentioned: \n    - Disaster Group\n    - Disaster Type\n    - Disaster Date (YMD)\n    - Country\n    - Geographical '
# Processing:  12%|██▉                     | 197/1588 [1:46:14<8:00:07, 20.71s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the provided information, we need to identify fields mentioned in the description. These fields are:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Da'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the provided information, we need to identify fields mentioned in the description. These fields are:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Da'
# Processing:  13%|██▉                    | 199/1588 [1:47:17<10:06:05, 26.18s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided text and references, I will extract relevant information from the disaster description. Here is the extracted information in JSON format:\n'
# Processing:  13%|███                    | 208/1588 [1:52:21<10:43:01, 27.96s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted JSON object:\n\n```\n{\n    "output_values": {\n        "Event": {\n            "Disaster Group": "Climatological",\n            "Disaster Type":'
# Processing:  13%|███                    | 209/1588 [1:52:59<11:52:48, 31.01s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the extracted information from the text:\n\n```\n{\n    "Event": {\n        "Disaster Group": null,\n        "Disaster Type": null,\n        "Disaster Date (YM'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the extracted information from the text:\n\n```\n{\n    "Event": {\n        "Disaster Group": null,\n        "Disaster Type": null,\n        "Disaster Date (YM'
# Processing:  14%|███▏                   | 221/1588 [1:59:02<11:29:34, 30.27s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the given FIELD_SCHEMA and DISASTER_DESCRIPTION, here are the required fields:\n\n* Event: \n\t+ Disaster Group\n\t+ Disaster Type\n\t+ Disaster Date (YMD)\n\t+ '
# Processing:  14%|███▏                   | 223/1588 [1:59:57<10:20:50, 27.29s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n        "Disaster Date (YMD'
# Processing:  14%|███▏                   | 224/1588 [2:00:50<13:18:25, 35.12s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the extracted information based on the provided fields and values:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Typ'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the extracted information based on the provided fields and values:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Typ'
# Processing:  14%|███▎                   | 226/1588 [2:01:59<12:50:10, 33.93s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Based on the provided information, here are the fields mentioned in the disaster description that are marked as 'Required' or are mentioned even once:\n\n* Event:"
# Processing:  15%|███▎                   | 233/1588 [2:05:54<12:15:09, 32.55s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "According to the FIELD_SCHEMA, the following fields are mentioned (even once) or marked as 'Required' in DISASTER_DESCRIPTION:\n\n- Event (Disaster Group)\n- Disas"
# Processing:  15%|███▍                   | 234/1588 [2:06:11<10:31:19, 27.98s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the provided FIELD_SCHEMA and OUTPUT_FIELDS, I will list every field that is mentioned in the disaster description:\n\n1. Event\n\t* Disaster Group\n\t* Disa'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the provided FIELD_SCHEMA and OUTPUT_FIELDS, I will list every field that is mentioned in the disaster description:\n\n1. Event\n\t* Disaster Group\n\t* Disa'
# [WARN] Regen attempt 1 still not JSON. Head: "Here are the fields that are mentioned or marked as 'Required' in DISASTER_DESCRIPTION:\n\n1. Event\n2. Disaster Group\n3. Disaster Type\n4. Disaster Date (YMD)\n5. C"
# Processing:  15%|███▍                   | 241/1588 [2:09:57<11:08:07, 29.76s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Refer FIELD_SCHEMA first:\n```\n{"Event": {"Disaster Group": {"Type": "Categorical", "Required": true, "Description": "Top-level hazard class; see disaster_classi'
# Processing:  16%|███▌                   | 247/1588 [2:13:41<13:19:44, 35.78s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Based on the given information, here are the fields that are mentioned or marked as 'Required':\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Co"
# Processing:  16%|███▌                   | 248/1588 [2:14:02<11:36:01, 31.17s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the given information, I will extract the required fields from DISASTER_DESCRIPTION.\n\n**DISASTER_DESCRIPTION:**\n"On 2 September 2022, the Civil Defense'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the given information, I will extract the required fields from DISASTER_DESCRIPTION.\n\n**DISASTER_DESCRIPTION:**\n"On 2 September 2022, the Civil Defense'
# Processing:  16%|███▊                   | 262/1588 [2:20:57<11:23:20, 30.92s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'The required fields mentioned are:\n\nEvent:\nDisaster Group\nDisaster Type\nDisaster Date (YMD)\n\nGeographical Information:\nCountry\nGeographical Level 0\nGeographical'
# Processing:  17%|███▉                   | 270/1588 [2:25:25<12:13:31, 33.39s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information from the provided DISASTER_DESCRIPTION and the desired output:\n\n```\n{\n    "Event": {\n        "fields": "values",\n        "Disa'
# Processing:  18%|████                   | 278/1588 [2:29:27<10:40:57, 29.36s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information in a single JSON object that conforms precisely to OUTPUT_VALUES:\n\n{\n    "output_values": {\n        "Event": {\n            "fi'
# Processing:  18%|████                   | 279/1588 [2:30:20<13:19:59, 36.67s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the extracted information in the required JSON format:\n\n`{"output_values": {"Event": {"Disaster Group": "Hydrological", "Disaster Type": "Flood"}, "Geog'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the extracted information in the required JSON format:\n\n`{"output_values": {"Event": {"Disaster Group": "Hydrological", "Disaster Type": "Flood"}, "Geog'
# Processing:  18%|████                   | 284/1588 [2:33:16<12:56:51, 35.74s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided `DISASTER_DESCRIPTION` and `EXTRACTED_FIELDS`, here is the extracted information:\n\n**Event**\n\n* **Disaster Group**: Hydrological\n* **Disas'
# Processing:  18%|████▏                  | 288/1588 [2:35:55<12:59:56, 36.00s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the `DISASTER_DESCRIPTION` and `EXTRACTED_FIELDS`, I extracted the relevant information as follows:\n\n**Event**\n\n* **Disaster Group**: Climatological\n* '
# Processing:  18%|████▏                  | 289/1588 [2:36:35<13:21:02, 37.00s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the provided DISASTER_DESCRIPTION and EXTRACTED_FIELDS, I can extract the required information:\n\n**Extracted Information:**\n\n- **Event**: \n  - Disaster'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the provided DISASTER_DESCRIPTION and EXTRACTED_FIELDS, I can extract the required information:\n\n**Extracted Information:**\n\n- **Event**: \n  - Disaster'
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the list of required field names:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaser Date (YMD)\n4. Country\n5. Number of affected'
# Processing:  18%|████▏                  | 290/1588 [2:37:01<12:09:50, 33.74s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'The mentioned fields are:\n- Event: Disaster Group, Disaster Type, Disaster Date (YMD), Cause\n- Geographical Information: Country, Geographical Level 0, Location'
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information from the given DISASTER_DESCRIPTION:\n\n```json\n{\n    "output_values": {\n        "Event": {\n            "Disaster Group": "Biolo'
# Processing:  18%|████▏                  | 291/1588 [2:38:01<15:05:06, 41.87s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the provided inputs, here is the extracted information in JSON format:\n\n```\n{\n    "output_values": {\n        "Event": {\n            "Disaster Group": "'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the provided inputs, here is the extracted information in JSON format:\n\n```\n{\n    "output_values": {\n        "Event": {\n            "Disaster Group": "'
# Processing:  18%|████▏                  | 293/1588 [2:39:17<14:31:27, 40.38s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'The output should be as follows:\n\nJSON object that conforms precisely to OUTPUT_FIELDS:\n{\n    "Event": ["Disaster Group", "Disaster Type", "Cause"],\n    "Geogra'
# Processing:  19%|████▎                  | 294/1588 [2:39:44<13:07:07, 36.50s/it]
# [WARN] Regen attempt 2 still not JSON. Head: "Based on the given FIELD_SCHEMA, we need to list every field that is mentioned or marked as 'Required' in DISASTER_DESCRIPTION.\n\nHere are the fields that are me"
# [WARN] Still not valid JSON after regenerations. Head: "Based on the given FIELD_SCHEMA, we need to list every field that is mentioned or marked as 'Required' in DISASTER_DESCRIPTION.\n\nHere are the fields that are me"
# Processing:  19%|████▎                  | 298/1588 [2:42:09<12:51:51, 35.90s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the field names mentioned or marked as \'Required\' in the disaster description:\n\n* "Disaster Group"\n* "Disaster Type"\n\nNow, we will create a JSON object'
# Processing:  19%|████▌                   | 306/1588 [2:46:16<8:42:00, 24.43s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Field names mentioned or marked as 'Required' in DISASTER_DESCRIPTION:\n\n1. Disaster Group\n2. Disaster Type\n3. Country\n4. Geographical Level 0\n5. Number of affec"
# Processing:  19%|████▋                   | 307/1588 [2:46:38<8:26:04, 23.70s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'The fields mentioned are:\n\n* Event: Disaster Group, Disaster Type, Disaster Date (YMD)\n* Geographical Information: Country, Geographical Level 0\n* Cause: \n* Mag'
# [WARN] Still not valid JSON after regenerations. Head: 'The fields mentioned are:\n\n* Event: Disaster Group, Disaster Type, Disaster Date (YMD)\n* Geographical Information: Country, Geographical Level 0\n* Cause: \n* Mag'
# [WARN] Regen attempt 1 still not JSON. Head: 'The input fields mentioned in DISASTER_DESCRIPTION:\n```\n"Disaster Group", "Disaster Type", "Cause", "Disaster Date (YMD)", "Country", "Geographical Level 0", "G'
# Processing:  19%|████▋                   | 308/1588 [2:46:56<7:45:01, 21.80s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'In order to generate the output JSON object, we need to extract all relevant fields from both EXAMPLE2_STAGE1 and our new example.\n\nThe "Required" boolean value'
# [WARN] Still not valid JSON after regenerations. Head: 'In order to generate the output JSON object, we need to extract all relevant fields from both EXAMPLE2_STAGE1 and our new example.\n\nThe "Required" boolean value'
# [WARN] Regen attempt 1 still not JSON. Head: 'From the given text, we can extract the following fields:\n\n* Event: \n    - Disaster Group\n    - Disaster Type\n    - Disaster Date (YMD)\n* Geographical Informati'
# Processing:  20%|████▌                  | 315/1588 [2:50:49<11:01:15, 31.17s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the given text, I have identified the required fields:\n\n**Event**\n\n* Disaster Group\n* Disaster Type\n\n**Geographical Information**\n\n* Country: Honduras\n'
# Processing:  20%|████▊                   | 316/1588 [2:51:03<9:15:55, 26.22s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here are the required fields:\n\nEvent\n\t* Disaster Group: fire\n\t* Disaster Type: fire\n\t* Disaster Date (YMD): "Saturday, 2 October 2021"\n\nGeographical Information'
# [WARN] Still not valid JSON after regenerations. Head: 'Here are the required fields:\n\nEvent\n\t* Disaster Group: fire\n\t* Disaster Type: fire\n\t* Disaster Date (YMD): "Saturday, 2 October 2021"\n\nGeographical Information'
# Processing:  20%|████▊                   | 320/1588 [2:52:59<9:35:23, 27.23s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the fields mentioned in the description:\n\n* Event:\n\t+ "Disaster Group"\n\t+ "Disaster Type"\n\t+ "Disaster Date (YMD)"\n\t+ Cause\n* Geographical Information:'
# Processing:  20%|████▊                   | 321/1588 [2:53:20<8:51:22, 25.16s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here are the field names mentioned in the disaster description:\n\nEvent:\n- Disaster Group\n- Disaster Type\n- Disaster Date (YMD)\n\nGeographical Information:\n- Coun'
# [WARN] Still not valid JSON after regenerations. Head: 'Here are the field names mentioned in the disaster description:\n\nEvent:\n- Disaster Group\n- Disaster Type\n- Disaster Date (YMD)\n\nGeographical Information:\n- Coun'
# Processing:  20%|████▋                  | 325/1588 [2:55:16<10:04:17, 28.71s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "To process this disaster description, you should list every field that is mentioned or marked as 'Required' in the DISASTER_DESCRIPTION.\n\nHere are the fields me"
# Processing:  21%|████▋                  | 326/1588 [2:55:58<11:33:31, 32.97s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'To generate the output JSON object for this disaster description, we need to refer to `FIELD_SCHEMA` and extract the required fields.\n\nFrom the given text, ment'
# Processing:  21%|████▋                  | 327/1588 [2:56:58<14:21:36, 41.00s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Here is the list of fields mentioned or marked as 'Required' in the DISASTER_DESCRIPTION:\n\n* Event:\n\t+ Disaster Group\n\t+ Disaster Type\n\t+ Cause\n* Geographical I"
# Processing:  21%|█████                   | 332/1588 [2:58:42<9:35:09, 27.48s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Based on the provided reference examples and field schema, I can identify the relevant fields mentioned or marked as 'Required' in DISASTER_DESCRIPTION.\n\nHere i"
# Processing:  22%|█████▏                  | 342/1588 [3:03:58<9:51:24, 28.48s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the input DESCRIPTION:\n\nThe torrential rains of 7 – 12 May 2021 triggered floods, landslides and mudflows in many of the country’s districts. The large'
# Processing:  22%|█████▏                  | 343/1588 [3:04:26<9:47:34, 28.32s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'From the provided disaster description, I found the following required fields:\n\n```\nDisaster Group\nDisaster Type\nCountry\nGeographical Level 0\nEvent Cause\nEvent '
# [WARN] Still not valid JSON after regenerations. Head: 'From the provided disaster description, I found the following required fields:\n\n```\nDisaster Group\nDisaster Type\nCountry\nGeographical Level 0\nEvent Cause\nEvent '
# Processing:  22%|█████▎                  | 348/1588 [3:06:42<9:24:18, 27.30s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'The fields mentioned in DISASTER_DESCRIPTION that need to be extracted for "Event", "Geographical Information", and "Effect" are:\n\n- Event: Disaster Group, Disa'
# Processing:  22%|█████                  | 349/1588 [3:07:22<10:39:27, 30.97s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Here are all the fields that are mentioned or marked as 'Required' in DISASTER_DESCRIPTION:\n\n* Event:\n    + Disaster Group\n    + Disaster Type\n    + Disaster Da"
# Processing:  22%|█████                  | 350/1588 [3:07:47<10:02:18, 29.19s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Here are the fields mentioned or marked as 'Required' in the provided description:\n\n* Event: Disaster Group, Disaster Type\n* Geographical Information: Country, "
# Processing:  22%|█████                  | 353/1588 [3:09:41<12:16:13, 35.77s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided information, here is the list of fields mentioned in the disaster description:\n\n* Disaster Group\n* Disaster Type\n* Disaster Date (YMD)\n* C'
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information from the given disaster description:\n\n```\n{"output_values": {\n    "Event": {\n        "Disaster Group": "Climatological",\n     '
# Processing:  22%|█████▏                 | 354/1588 [3:10:35<14:10:09, 41.34s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the extracted information in JSON format:\n\n{"output_values": {\n"Event": {\n"fields": {\n"Disaster Group": "Climatological",\n"Disaster Type": "Flood",  # A'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the extracted information in JSON format:\n\n{"output_values": {\n"Event": {\n"fields": {\n"Disaster Group": "Climatological",\n"Disaster Type": "Flood",  # A'
# Processing:  22%|█████▏                 | 357/1588 [3:12:02<11:06:50, 32.50s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information from the DISASTER_DESCRIPTION:\n\n```\n{"Event":\n    {"fields": {\n        "Disaster Group": "Biological",\n        "Disaster Type"'
# Processing:  23%|█████▏                 | 358/1588 [3:12:57<13:23:22, 39.19s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the extracted information:\n\n```\n{\n    "Event": {\n        "fields": {\n            "Disaster Group": "Climatological",\n            "Disaster Type": "Droug'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the extracted information:\n\n```\n{\n    "Event": {\n        "fields": {\n            "Disaster Group": "Climatological",\n            "Disaster Type": "Droug'
# Processing:  23%|█████▌                  | 366/1588 [3:16:31<8:21:29, 24.62s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'From the given DISASTER_DESCRIPTION, I will extract the necessary information and present it in a JSON object that conforms to the OUTPUT_VALUES. Here is the ou'
# Processing:  24%|█████▍                 | 379/1588 [3:23:46<12:12:44, 36.36s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the input, I extracted the relevant information from the DISASTER_DESCRIPTION and created a JSON object that conforms to the OUTPUT_VALUES format. Here'
# Processing:  24%|█████▌                 | 380/1588 [3:24:36<13:34:28, 40.45s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the extracted information from the provided text:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n    '
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the extracted information from the provided text:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n    '
# Processing:  24%|█████▌                 | 384/1588 [3:26:36<10:56:34, 32.72s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Below are the fields mentioned (even once) or marked as 'Required' in DISASTER_DESCRIPTION:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Cause\n"
# Processing:  25%|█████▋                 | 391/1588 [3:31:15<12:48:23, 38.52s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the desired output in JSON format:\n\n{\n    "Event": {\n        "fields": {\n            "Disaster Group": "Hydrological",\n            "Disaster Type": Cate'
# Processing:  25%|█████▋                 | 393/1588 [3:32:30<12:19:06, 37.11s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided text and schema, I will extract the relevant information for the given fields and values.\n\n**EXTRACTED_FIELDS**\n\n* Event:\n  - Disaster Gro'
# Processing:  25%|█████▋                 | 394/1588 [3:33:05<12:09:23, 36.65s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the output:\n\n```\n{\n    "Event": {\n        "fields": {\n            "Disaster Group": "Hydrological",\n            "Disaster Type": "Flood"\n        },\n    '
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the output:\n\n```\n{\n    "Event": {\n        "fields": {\n            "Disaster Group": "Hydrological",\n            "Disaster Type": "Flood"\n        },\n    '
# Processing:  25%|█████▊                 | 401/1588 [3:37:20<11:57:38, 36.27s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the list of required fields:\n\n"Event", "Country", "Geographical Level 1", "Disaster Date (YMD)"'
# Processing:  26%|█████▉                 | 409/1588 [3:42:09<11:56:14, 36.45s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information:\n\n```\n{\n    "Event": {\n        "fields": {\n            "Disaster Group": "Climatological",\n            "Disaster Type": "",\n  '
# Processing:  26%|█████▉                 | 411/1588 [3:43:22<11:33:11, 35.34s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the field names mentioned in the disaster description:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Cause\n5. Country\n6. Geographical L'
# Processing:  26%|██████▏                 | 412/1588 [3:43:41<9:59:53, 30.61s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Field names:\n* Event: Disaster Group\n* Geographical Information: Country\n* Geographical Level 0\n* Geographical Level 1\n* Location\n* Effect: Number of Deaths\n* N'
# [WARN] Still not valid JSON after regenerations. Head: 'Field names:\n* Event: Disaster Group\n* Geographical Information: Country\n* Geographical Level 0\n* Geographical Level 1\n* Location\n* Effect: Number of Deaths\n* N'
# Processing:  26%|██████                 | 417/1588 [3:46:32<11:13:13, 34.49s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided information, I will extract relevant fields and values from the DISASTER_DESCRIPTION text.\n\nEvent: \n1. Disaster Group: Hydrological\n2. Dis'
# Processing:  27%|██████▏                | 426/1588 [3:51:31<10:15:23, 31.78s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the fields mentioned in the given text:\n\n* Disaster Group\n* Disaster Type\n* Disaster Date (YMD)\n* Cause\n* Country\n* Geographical Level 0\n* Number of af'
# Processing:  27%|██████▍                 | 427/1588 [3:51:50<9:01:37, 27.99s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the FIELD_SCHEMA, here are the fields mentioned in the DISASTER_DESCRIPTION:\n\n* Event: Disaster Group\n* Event: Disaster Type\n* Event: Cause\n* Event: Di'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the FIELD_SCHEMA, here are the fields mentioned in the DISASTER_DESCRIPTION:\n\n* Event: Disaster Group\n* Event: Disaster Type\n* Event: Cause\n* Event: Di'
# Processing:  27%|██████▍                 | 428/1588 [3:52:00<7:15:57, 22.55s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided text, here is the extracted information in JSON format:\n\n```json\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disas'
# Processing:  28%|██████▋                 | 442/1588 [3:58:48<7:56:17, 24.94s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Field names that are mentioned (even once) or are marked as 'Required' in the provided text are:\n\n* Disaster Group\n* Disaster Type\n* Disaster Date (YMD)\n* Cause"
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information:\n\n**JSON Object:**\n```json\n{\n    "Event": {\n        "fields": {\n            "Disaster Group": "Biological",\n            "Disas'
# Processing:  28%|██████▌                | 449/1588 [4:02:47<10:17:10, 32.51s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the FIELD_SCHEMA, I will list all fields that are mentioned in the disaster description:\n\n- Event\n   - Disaster Group: Categorical\n   - Disaster Type: '
# Processing:  30%|███████▎                | 481/1588 [4:18:04<9:00:36, 29.30s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the list of field names mentioned in the text:\n\n* Event: Disaster Group, Disaster Type, Disaster Date (YMD), Cause\n* Geographical Information: Country, '
# Processing:  30%|███████▎                | 482/1588 [4:18:36<9:11:33, 29.92s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided DISASTER_DESCRIPTION and EXTRACTED_FIELDS, I will extract the required information:\n\nEvent:\n\n* Disaster Group: Climatological (Hydrologica'
# Processing:  30%|██████▉                | 483/1588 [4:19:17<10:13:44, 33.32s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the output in JSON format:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n        "Disaster Date (YMD'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the output in JSON format:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n        "Disaster Date (YMD'
# Processing:  31%|███████▎                | 486/1588 [4:20:42<9:49:40, 32.11s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the output JSON object that conforms to OUTPUT_VALUES:\n\n```\n{\n    "Event": {\n        "fields": {\n            "Disaster Group": "Meteorological",\n       '
# Processing:  31%|███████▍                | 494/1588 [4:24:31<7:56:47, 26.15s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the JSON object extracted from the `DISASTER_DESCRIPTION` with information only on the fields specified in `EXTRACTED_FIELDS`.\n\n```\n{\n    "Event": {\n   '
# Processing:  31%|███████▏               | 495/1588 [4:25:23<10:18:47, 33.97s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the extracted information in JSON format:\n\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n        "Cause":'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the extracted information in JSON format:\n\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n        "Cause":'
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided information, here is a JSON object that conforms precisely to OUTPUT_FIELDS:\n\n{\n    "Event": ["Disaster Group", "Disaster Type", "Disaster'
# Processing:  32%|███████▎               | 506/1588 [4:31:26<11:06:11, 36.94s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the list of field names:\n\n* Event\n* Geographical Information\n* Effect'
# Processing:  32%|███████▊                | 515/1588 [4:36:12<9:04:39, 30.46s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the required field names based on your input:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Cause\n5. Country\n6. Geographical Level 1\n7.'
# Processing:  32%|███████▊                | 516/1588 [4:36:28<7:45:07, 26.03s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here are the required field names:\n\nEvent: Disaster Group, Disaster Type, Disaster Date (YMD), Cause\nGeographical Information: Country, Geographical Level 0\nEff'
# [WARN] Still not valid JSON after regenerations. Head: 'Here are the required field names:\n\nEvent: Disaster Group, Disaster Type, Disaster Date (YMD), Cause\nGeographical Information: Country, Geographical Level 0\nEff'
# Processing:  33%|███████▉                | 525/1588 [4:40:18<6:35:43, 22.34s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'From the text:\n\n* "Event" fields: \n  * Disaster Group\n  * Disaster Type\n  * Disaster Date (YMD)\n  * Cause (not mentioned, so assuming it can be skipped)\n\n* "Geo'
# Processing:  33%|███████▉                | 528/1588 [4:42:01<9:05:36, 30.88s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Here's the list of fields mentioned:\n\n1. Event\n\t* Disaster Group\n\t* Disaster Type\n\t* Disaster Date (YMD)\n2. Geographical Information\n\t* Country\n3. Effect\n\t* Num"
# Processing:  34%|████████                | 532/1588 [4:43:33<6:32:29, 22.30s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'The field names mentioned are:\n\n- Disaster Group\n- Disaster Type\n- Disaster Date (YMD)\n- Cause\n- Country\n- Geographical Level 0\n- Location\n- Number of affected\n'
# Processing:  34%|████████                | 533/1588 [4:43:47<5:49:24, 19.87s/it]
# [WARN] Regen attempt 2 still not JSON. Head: "The following fields are mentioned or marked as 'Required' in DISASTER_DESCRIPTION:\n\n* Event: Disaster Group\n* Event: Disaster Type\n* Geographical Information: "
# [WARN] Still not valid JSON after regenerations. Head: "The following fields are mentioned or marked as 'Required' in DISASTER_DESCRIPTION:\n\n* Event: Disaster Group\n* Event: Disaster Type\n* Geographical Information: "
# Processing:  34%|████████                | 537/1588 [4:46:10<9:47:44, 33.55s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the mentioned fields:\n\n1. Event: \n   - Disaster Group\n   - Disaster Type\n   - Disaster Date (YMD)\n   - Cause\n\n2. Geographical Information: \n   - Countr'
# Processing:  34%|████████▏               | 542/1588 [4:49:02<9:45:10, 33.57s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Based on the provided FIELD_SCHEMA and OUTPUT_FIELDS, here are the relevant fields mentioned or marked as 'Required' in the given disaster description:\n\nField n"
# Processing:  34%|████████▏               | 544/1588 [4:49:56<9:02:52, 31.20s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the required fields:\n\n1. Event: \n   * Disaster Group\n   * Disaster Type\n   * Disaster Date (YMD)\n\n2. Geographical Information:\n   * Country\n   * Geogra'
# Processing:  34%|████████▏               | 545/1588 [4:50:12<7:44:35, 26.73s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the provided information, here are the required fields:\n\n1. Event:\n\t* Disaster Group\n    * Disaster Type\n    * Disaster Date (YMD)\n\n2. Geographical Inf'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the provided information, here are the required fields:\n\n1. Event:\n\t* Disaster Group\n    * Disaster Type\n    * Disaster Date (YMD)\n\n2. Geographical Inf'
# Processing:  35%|████████▍               | 555/1588 [4:55:04<8:32:28, 29.77s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'After processing DISASTER_DESCRIPTION and EXTRACTED.Fields, we can extract the following information:\n\n**Event**\n- Disaster Group: Meteorological\n- Disaster Typ'
# Processing:  35%|████████▍               | 560/1588 [4:58:04<9:10:28, 32.13s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the fields mentioned in the text:\n\n* Event: Disaster Group, Disaster Type, Disaster Date (YMD), Cause\n* Geographical Information: Country, Geographical'
# Processing:  35%|████████▍               | 562/1588 [4:58:43<7:19:38, 25.71s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided information, here is the extracted data from the DISASTER_DESCRIPTION:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Biological",\n     '
# Processing:  36%|████████▌               | 569/1588 [5:02:27<8:26:18, 29.81s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Based on the given FIELD_SCHEMA and EXAMPLE_STAGE1, here are the fields mentioned or marked as 'Required' in the DISASTER_DESCRIPTION:\n\n* Event: Disaster Group,"
# Processing:  36%|████████▋               | 571/1588 [5:03:47<9:42:26, 34.36s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'After analyzing the input text and the field schema, we can extract the following information from the provided DISASTER_DESCRIPTION:\n\n```\nEvent:\n- Disaster Gro'
# Processing:  36%|████████▎              | 577/1588 [5:07:35<10:01:05, 35.67s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided text and FIELD_SCHEMA, CATEGORICAL_VALUES, OUTPUT_VALUES, I extracted the necessary information. Here is a single JSON object that conform'
# Processing:  36%|████████▍              | 579/1588 [5:09:03<10:58:11, 39.14s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Please extract all information regarding only the fields in EXTRACTED_FIELDS from text DISASTER_DESCRIPTION, referring to FIELD_SCHEMA and using only the catego'
# Processing:  37%|████████▍              | 580/1588 [5:09:53<11:53:42, 42.48s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'After analyzing the DISASTER_DESCRIPTION, we can extract the following fields:\n\n```json\n{\n    "Event": {\n        "Disaster Group": "Biological",\n        "Disast'
# [WARN] Still not valid JSON after regenerations. Head: 'After analyzing the DISASTER_DESCRIPTION, we can extract the following fields:\n\n```json\n{\n    "Event": {\n        "Disaster Group": "Biological",\n        "Disast'
# Processing:  37%|████████▉               | 590/1588 [5:15:08<9:02:23, 32.61s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the FIELD_SCHEMA, here are the fields that were mentioned in the given disaster description.\n\nThe "Event" includes:\n- Disaster Group\n- Disaster Type\n- '
# Processing:  37%|████████▉               | 591/1588 [5:15:48<9:40:07, 34.91s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'After extracting the relevant information from the DISASTER_DESCRIPTION, here is the JSON object that conforms to OUTPUT_VALUES:\n\n{\n    "output_values": {\n     '
# Processing:  37%|████████▌              | 592/1588 [5:16:37<10:46:53, 38.97s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'The output is as follows:\n\n```\n{\n    "Event": {\n        "fields": {\n            "Disaster Group": "Biological",\n            "Disaster Type": "Epidemic",\n       '
# [WARN] Still not valid JSON after regenerations. Head: 'The output is as follows:\n\n```\n{\n    "Event": {\n        "fields": {\n            "Disaster Group": "Biological",\n            "Disaster Type": "Epidemic",\n       '
# Processing:  37%|████████▌              | 594/1588 [5:17:51<10:39:42, 38.61s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Let\'s extract the necessary information according to the FIELD_SCHEMA.\n\nFrom the description:\n- The "Event" is a series of violent winds.\n- The "Disaster Group"'
# Processing:  37%|████████▉               | 595/1588 [5:18:16<9:32:18, 34.58s/it]
# [WARN] Regen attempt 2 still not JSON. Head: "Here are the fields mentioned or marked as 'Required' in the disaster description:\n\n1. Event\n2. Disaster Group\n3. Disaster Type\n4. Disaster Date (YMD)\n5. Cause\n"
# ...
# Processing:  87%|███████████████████▏  | 1383/1588 [12:21:53<2:16:46, 40.03s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'The required field names to be mentioned are:\n\n* Disaster Group\n* Disaster Type\n* Disaster Date (YMD)\n* Country\n* Geographical Level 0\n* Location\n* Number of De'
# Processing:  88%|███████████████████▎  | 1390/1588 [12:24:48<1:20:55, 24.52s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the given DISASTER_DESCRIPTION and EXTRACTED_FIELDS, I will extract the required information.\n\n**Disaster Group:** Hydrological (based on record level '
# Processing:  88%|███████████████████▎  | 1395/1588 [12:27:33<1:35:06, 29.57s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "The output field names mentioned even once or marked as 'Required' are:\n\n1. Disaster Group\n2. Disaster Type\n3. Country\n4. Geographical Level 0\n5. Disaster Date "
# Processing:  88%|███████████████████▍  | 1400/1588 [12:30:02<1:34:31, 30.17s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided disaster description, here is the extracted information in JSON format:\n\n```json\n{\n    "Event": {\n        "Disaster Group": "Hydrological"'
# Processing:  89%|███████████████████▍  | 1407/1588 [12:33:56<1:24:39, 28.07s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided information, here is the extracted data in JSON format that conforms to the OUTPUT_VALUES:\n\n```\n{\n    "output_values": {\n        "Event": '
# Processing:  89%|███████████████████▌  | 1413/1588 [12:38:03<1:30:16, 30.95s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the mandatory fields for the given disaster description:\n\n1. "Disaster Group" (Required)\n2. "Disaster Type" (Required)\n3. "Event Date (YMD)" (Not Requi'
# Processing:  89%|███████████████████▌  | 1414/1588 [12:38:24<1:21:05, 27.97s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here are the mentioned field names:\n\n1. Event\n2. Country\n3. Geographical Level 0\n4. Disaster Group\n5. Disaster Type\n6. Disaster Date (YMD)\n7. Cause\n8. Number of'
# [WARN] Still not valid JSON after regenerations. Head: 'Here are the mentioned field names:\n\n1. Event\n2. Country\n3. Geographical Level 0\n4. Disaster Group\n5. Disaster Type\n6. Disaster Date (YMD)\n7. Cause\n8. Number of'
# Processing:  89%|███████████████████▋  | 1417/1588 [12:39:57<1:23:49, 29.41s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the list of fields mentioned in the text:\n\n- Event: Disaster Group, Disaster Type, Disaster Date (YMD), Cause\n- Geographical Information: Country, Geogr'
# Processing:  89%|███████████████████▋  | 1419/1588 [12:41:01<1:28:24, 31.39s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information in JSON format, conforming to the OUTPUT_VALUES schema:\n\n```\n{\n    "Event": {\n        "fields": {\n            "Disaster Group"'
# Processing:  89%|███████████████████▋  | 1420/1588 [12:41:49<1:41:46, 36.35s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the extracted information from the given text:\n\n**Event**\n\n* Disaster Group: Meteorological\n* Disaster Type: Storm\n* Disaster Date (YMD): 1993-10-06\n* C'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the extracted information from the given text:\n\n**Event**\n\n* Disaster Group: Meteorological\n* Disaster Type: Storm\n* Disaster Date (YMD): 1993-10-06\n* C'
# Processing:  90%|███████████████████▊  | 1430/1588 [12:46:55<1:14:17, 28.21s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information from the given text:\n\n```\noutput_values = {\n    "Event": {\n        "fields": {\n            "Disaster Group": "Climatological",'
# Processing:  90%|███████████████████▉  | 1435/1588 [12:50:20<1:39:49, 39.15s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the list of fields mentioned:\n\n* Event: Disaster Group, Disaster Type, Disaster Date (YMD), Cause\n* Geographical Information: Country, Geographical Leve'
# Processing:  91%|███████████████████▉  | 1438/1588 [12:51:56<1:29:57, 35.98s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information in a single JSON object that conforms to OUTPUT_VALUES:\n\n```\n{\n    "output_values": {\n        "Event": {\n            "fields":'
# Processing:  91%|███████████████████▉  | 1439/1588 [12:52:58<1:48:41, 43.77s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the JSON output:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n        "Cause": "Torrential rains",\n'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the JSON output:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n        "Cause": "Torrential rains",\n'
# Processing:  91%|███████████████████▉  | 1440/1588 [12:53:29<1:39:01, 40.15s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Based on the provided FIELD_SCHEMA and OUTPUT_FIELDS, I will list every field that is mentioned (even once) or is marked as 'Required' in DISASTER_DESCRIPTION:\n"
# Processing:  92%|██████████████████████▏ | 1466/1588 [13:07:04<51:16, 25.22s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Based on the provided information and the examples given, I will extract the fields mentioned in the disaster description and mark them as 'Required' if they ar"
# Processing:  92%|██████████████████████▏ | 1468/1588 [13:07:57<52:28, 26.23s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the output in JSON format:\n\n{\n    "Event": {\n        "fields": {\n            "Disaster Group": "Biological",\n            "Disaster Type": null,\n        '
# Processing:  93%|██████████████████████▏ | 1471/1588 [13:09:47<59:27, 30.49s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the field names mentioned in the disaster description:\n\n* Disaster Group\n* Disaster Type\n* Disaster Date (YMD)\n* Cause\n* Magnitude\n* Magnitude Scale\n* '
# Processing:  93%|██████████████████████▏ | 1472/1588 [13:10:00<48:41, 25.19s/it]
# [WARN] Regen attempt 2 still not JSON. Head: "Here is the list of fields mentioned or marked as 'Required' in the DISASTER_DESCRIPTION:\n\nEvent:\n- Disaster Group\n- Disaster Type\nDisaster Date (YMD)\nCause\nMag"
# [WARN] Still not valid JSON after regenerations. Head: "Here is the list of fields mentioned or marked as 'Required' in the DISASTER_DESCRIPTION:\n\nEvent:\n- Disaster Group\n- Disaster Type\nDisaster Date (YMD)\nCause\nMag"
# Processing:  93%|██████████████████████▎ | 1477/1588 [13:12:22<46:08, 24.94s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the fields mentioned in the disaster description:\n\n1. Disaster Group\n2. Disaster Type\n3. Cause\n4. Country\n5. Geographical Level 1\n6. Number of Deaths\n7'
# Processing:  94%|██████████████████████▍ | 1485/1588 [13:15:20<36:53, 21.49s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "I shall list every field that is mentioned or marked as 'Required' in the given text:\n\n* Disaster Group\n* Disease Type\n* Disaster Date (YMD)\n* Cause\n* Country\n*"
# Processing:  94%|██████████████████████▍ | 1486/1588 [13:15:33<32:25, 19.08s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the provided information, here is the list of fields mentioned:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Cause\n5. Country\n6. Geogr'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the provided information, here is the list of fields mentioned:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Cause\n5. Country\n6. Geogr'
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided information, here are the fields mentioned:\n\n1. Event\n2. Disaster Group\n3. Disaster Type\n4. Disaster Date (YMD)\n5. Cause\n6. Country\n7. Geo'
# Processing:  94%|██████████████████████▌ | 1490/1588 [13:17:32<45:21, 27.77s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Here are the fields mentioned (even once) or marked as 'Required' in DISASTER_DESCRIPTION:\n\n1. Event\n2. Disaster Group\n3. Disaster Type\n4. Disaster Date (YMD)\n5"
# Processing:  94%|██████████████████████▌ | 1491/1588 [13:18:08<49:02, 30.34s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information from the text:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Meteorological",\n        "Disaster Type": "Storm",\n        "Di'
# Processing:  94%|██████████████████████▌ | 1492/1588 [13:18:56<57:12, 35.76s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the DISASTER_DESCRIPTION, I extracted the relevant information for each field in EXTRACTED_FIELDS and constructed a JSON object that conforms to OUTPUT'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the DISASTER_DESCRIPTION, I extracted the relevant information for each field in EXTRACTED_FIELDS and constructed a JSON object that conforms to OUTPUT'
# Processing:  94%|██████████████████████▌ | 1494/1588 [13:20:08<56:22, 35.99s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'After extracting the relevant information from the DISASTER_DESCRIPTION, we get:\n\nEVENT: \n- Disaster Group: Geophysical\n- Disaster Type: Earthquake\n- Disaster D'
# Processing:  94%|██████████████████████▌ | 1495/1588 [13:20:50<58:30, 37.75s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the GIVEN_INPUT, I can extract the relevant information from the DISASTER_DESCRIPTION and return a JSON object that conforms to the OUTPUT_VALUES. Here'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the GIVEN_INPUT, I can extract the relevant information from the DISASTER_DESCRIPTION and return a JSON object that conforms to the OUTPUT_VALUES. Here'
# Processing:  94%|██████████████████████▌ | 1497/1588 [13:22:07<56:51, 37.49s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided DISASTER_DESCRIPTION and EXTRACTED_FIELDS, I can extract the relevant information and format it into a JSON object that conforms to the OU'
# Processing:  94%|████████████████████▊ | 1498/1588 [13:22:58<1:02:20, 41.56s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the provided text, I will extract the relevant information and create a JSON object in accordance with the OUTPUT_VALUES.\n\nHere is the extracted inform'
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the provided text, I will extract the relevant information and create a JSON object in accordance with the OUTPUT_VALUES.\n\nHere is the extracted inform'
# Processing:  96%|██████████████████████▉ | 1519/1588 [13:32:12<29:04, 25.28s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'After extracting the relevant information from the disaster description, we can create a JSON object that conforms precisely to the `OUTPUT_VALUES` schema. Here'
# Processing:  96%|██████████████████████▉ | 1520/1588 [13:33:15<41:45, 36.84s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Based on the provided text, EXTRACTED_FIELDS, and CATEGORICAL_VALUES, here is the extracted information:\n\n```\n{\n    "output_values": {\n        "Event": {\n      '
# [WARN] Still not valid JSON after regenerations. Head: 'Based on the provided text, EXTRACTED_FIELDS, and CATEGORICAL_VALUES, here is the extracted information:\n\n```\n{\n    "output_values": {\n        "Event": {\n      '
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided information, I will extract the required fields from the description and then match them with the OUTPUT_FIELDS schema.\n\nRequired Fields:\n'
# Processing:  96%|███████████████████████ | 1523/1588 [13:34:40<33:47, 31.19s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'From the provided description, we can identify the following fields mentioned in DISASTER_DESCRIPTION:\n\n\n```\nRequired Fields: \nEvent\nGeographical Information\nEf'
# Processing:  96%|███████████████████████ | 1524/1588 [13:35:13<33:44, 31.64s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Based on the provided FIELD_SCHEMA and EXAMPLE1_STAGE1, the fields that are mentioned (even once) or is marked as 'Required' in DISASTER_DESCRIPTION are:\n\nEvent"
# Processing:  96%|███████████████████████ | 1526/1588 [13:36:01<29:07, 28.19s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Based on FIELD_SCHEMA and DISASTER_DESCRIPTION, I will list every field that is mentioned or marked as 'Required' in DISASTER_DESCRIPTION:\n\n1. Event\n   - Disast"
# Processing:  96%|███████████████████████ | 1528/1588 [13:37:07<30:19, 30.33s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided information, here is the extracted JSON object:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Geophysical",\n        "Disaster Type": "E'
# Processing:  96%|███████████████████████ | 1530/1588 [13:38:49<38:10, 39.49s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the FIELD_SCHEMA and EXAMPLE1_STAGE1, I will extract the required fields mentioned in the disaster description.\n\nThe event group is "Hazard", with a ty'
# Processing:  96%|███████████████████████▏| 1532/1588 [13:40:16<37:49, 40.53s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "To extract the required information, let's go through the given parameters and functions:\n\n1. **EXTRACTED_FIELDS**: The fields to be extracted from the DISASTER"
# Processing:  97%|███████████████████████▏| 1533/1588 [13:40:59<37:47, 41.22s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here are the field names mentioned or marked as \'Required\' from the DISASTER_DESCRIPTION:\n\n* "Event": \n    * Disaster Group\n    * Disaster Type\n    * Disaster D'
# Processing:  98%|███████████████████████▍| 1554/1588 [13:51:35<16:56, 29.90s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Here is the extracted information from the provided DISASTER_DESCRIPTION:\n\n```json\n{\n    "description": "The UNDRO/UNDP resident coordinator reports that a doub'
# Processing:  98%|███████████████████████▌| 1555/1588 [13:52:19<18:46, 34.14s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Here is the extracted information in JSON format:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Transport",\n        "Disaster Type": "Water", \n        "Disas'
# [WARN] Still not valid JSON after regenerations. Head: 'Here is the extracted information in JSON format:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Transport",\n        "Disaster Type": "Water", \n        "Disas'
# Processing:  98%|███████████████████████▌| 1560/1588 [13:54:20<09:44, 20.88s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided DISASTER_DESCRIPTION and EXTRACTED_FIELDS, here is the extracted information:\n\n```\n{\n    "Event": {\n        "Disaster Group": "Hydrologica'
# Processing:  98%|███████████████████████▌| 1561/1588 [13:55:12<13:38, 30.32s/it]
# [WARN] Regen attempt 2 still not JSON. Head: 'Below is the output in JSON format:\n\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n        "Disaster Date (YMD)":'
# [WARN] Still not valid JSON after regenerations. Head: 'Below is the output in JSON format:\n\n{\n    "Event": {\n        "Disaster Group": "Hydrological",\n        "Disaster Type": "Flood",\n        "Disaster Date (YMD)":'
# Processing:  98%|███████████████████████▌| 1563/1588 [13:56:07<11:45, 28.20s/it]
# [WARN] Regen attempt 1 still not JSON. Head: 'Based on the provided information, here are the fields mentioned:\n\n1. Disaster Group\n2. Disaster Type\n3. Disaster Date (YMD)\n4. Cause\n5. Country\n6. Geographical'
# Processing:  99%|███████████████████████▊| 1572/1588 [13:59:40<05:23, 20.21s/it]
# [WARN] Regen attempt 1 still not JSON. Head: "Based on the provided FIELD_SCHEMA and DISASTER_DESCRIPTION, I will list every field that is mentioned (even once) or is marked as 'Required' in the DISASTER_DE"
# Processing: 100%|████████████████████████| 1588/1588 [14:09:05<00:00, 32.08s/it]
# Output saved to extracted_llama.csv
